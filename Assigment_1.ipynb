# %%
# questions

'''
Question 1. Explain the basic structure of an HTML page. Why is it important to follow
this structure?
     - Basic structure of an HTML page is...
'''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Document</title>
</head>
<body>

</body>
</html>
'''
It is important to follow this structure because..

1. It ensures that browsers can correctly read and display the web page content.

2. It helps search engines and screen readers understand the page, improving SEO and accessibility.

3. It makes the code organized, easier to maintain and debug.

4. It follows web standards, so the page works properly on all browsers and devices.

Question 2: You’re building a small personal profile page. Which HTML tags will you
use to highlight your name as a heading, describe yourself in a paragraph, and
emphasize a key skill?
      - For highlighting name i will use <h1> tag
      - <p>I am a BCA FIRST YEAR student with a deep interest in web development and technology. I enjoy creating websites, learning new programming languages, and solving challenging problems and I am a passionate and curious learner with a keen interest in technology and creativity. Ever since my school days, I have enjoyed exploring how computers work and how websites are built, which inspired me to start learning HTML, CSS, and JavaScript. I consider myself a hardworking and dedicated individual who believes in continuous learning and self-improvement. Besides technology, I have a deep love for reading books and drawing, which help me think creatively and develop new ideas. One of my strongest skills is <strong>problem-solving</strong>, which allows me to approach challenges with patience and logical thinking. I enjoy working on projects that let me combine my technical knowledge with creativity, such as designing personal websites or small applications. In the future, I aim to become a skilled software developer, contribute innovative solutions to real-world problems, and keep growing both personally and professionally.</p>
      - <p> Basically i don't have any good skill right now but i have started to develop skills.
Question 3: Look at the code below. Can you find and fix the mistake?
<!-- This is an HTML comment
<h1>Welcome to my website</h1>
    - In this code, i can see that the comment section is not closed so to fix this code first we have to put "-->" sign in it then our code will look like..
'''
<!-- This is an HTML comment -->
<h1>Welcome to my website</h1>

'''
Question 4: You’re creating a form that asks the user to enter their name, select their
country from a list, and click a button to submit. Write the HTML code for this.
'''
    -  <!DOCTYPE html>
<html>
<head>
    <title>Simple User Form</title>
</head>
<body>

<h2>Form</h2>

<form action="#">
    <!-- Input for user's name -->
    <label for="name">Name:</label>
    <input type="text" id="name" name="name" required><br><br>

    <!-- Dropdown to select country -->
    <label for="country">Country:</label>
    <select id="country" name="country" required>
        <option value="">--Select Country--</option>
        <option value="India">India</option>
        <option value="USA">USA</option>
        <option value="UK">UK</option>
        <option value="Australia">Australia</option>
    </select><br><br>

    <!-- Submit button -->
    <button type="submit">Submit</button>
</form>

</body>
</html>

'''
Question 5: Write short HTML code to show your favorite fruits in a bulleted list and
your top 3 programming languages in a numbered list.
'''
   -   <!DOCTYPE html>
<html>
<head>
    <title>Fruits</title>
</head>
<body>

<h3>My Favorite Fruits</h3>
<ul>
    <li>Mango</li>
    <li>Banana</li>
    <li>Apple</li>
    <li>Orange</li>
</ul>

<h3>My Top 3 Programming Languages</h3>
<ol>
    <li>JavaScript</li>
    <li>Python</li>
    <li>Java</li>
</ol>

</body>
</html>

'''
Question 6: Ravi wants to leave a note in his HTML file so that only other developers
can see it, not the users on the website. How should he do this? Why are such notes
useful?
   - He can use HTML comments to leave a note in his HTML file so that only other developers can see it, and it does not appear on the actual website. An HTML comment is written using the special syntax <!-- comment goes here -->. For example, Ravi can write: <!-- This section displays the user profile -->. The browser completely ignores anything inside <!-- and -->, so these notes are never shown to website visitors. Such comments are very useful because they help developers understand the structure or purpose of the code, serve as reminders for future changes, and make it easier for other developers (or even Ravi himself later) to maintain and debug the code. In this way, comments improve the readability, collaboration, and maintainability of HTML files.

Question 7: Here’s a form snippet. Can you spot the error and rewrite the correct
version?
<form>
 <input name="email">
 <select>
 <option>India</option>
 </select>
 <button>Send</buton>
</form>
   - in this form snippet the type attribute is missing without it browser can't able to know what type of input is it, so the correct version is..
'''
<form>
    <input type="email" name="email">
    <select>
        <option>India</option>
    </select>
    <button>Send</button>
</form>
